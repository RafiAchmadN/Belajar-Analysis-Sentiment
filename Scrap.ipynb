# %%
# %pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in ./env/lib/python3.12/site-packages (1.2.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import app, reviews_all, Sort

scrape = reviews_all(
    'com.gaijingames.wtm',          # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=10000           # Jumlah maksimum ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
import csv


with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrape:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
import pandas as pd
app_reviews_df = pd.DataFrame(scrape)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)

# %%
app_reviews_df = pd.DataFrame(scrape)
 
# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  1f25bd96-d953-48eb-8041-30db4f9600af  Pengguna Google
# 1  eaf5a05c-9175-441b-b3c6-02be9480cd86  Pengguna Google
# 2  cd192b6e-c811-48d0-b4b5-67513de9974c  Pengguna Google
# 3  521d1f05-59ea-40fb-b296-e3e08fa3c31e  Pengguna Google
# 4  dca04877-1b66-43dc-8ae8-f0b6c15b971f  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  semenjak di update jadi sering error, server s...      1            281
# 1  Dari segi grafis sudah baik. →Keluhannya: 1. U...      5            369
# 2  Saran update kedepannya tambahkan detail suara...      5             46
# 3  dari segi gameplay menurutku udah baguslah apa...      5              5
# 4  Grafik maksimal di smartphone yang support jad...      5            153
#
#   reviewCreatedVersion                  at  \
# 0            1.19.2.42 2025-09-30 06:26:24
# 1            1.19.1.39 2025-09-21 21:44:47
# 2            1.19.2.42 2025-10-11 08:11:18
# 3            1.19.2.42 2025-10-11 14:42:25
# 4            1.18.1.11 2025-08-04 13:03:47
#
#                                         replyContent           repliedAt  \
# 0  Kami menghargai masukan Anda tentang masalah s... 2025-09-30 17:08:47
# 1  Kami sangat menghargai masukan Anda mengenai k... 2025-09-22 19:03:46
# 2  Kami sangat menghargai saran Anda tentang deta... 2025-10-08 18:36:43
# 3  Kami senang mendengar gameplay sudah memuaskan... 2025-10-20 18:49:07
# 4  Kami sangat menghargai masukan Anda tentang gr... 2025-08-04 18:53:11
#
#   appVersion
# 0  1.19.2.42
# 1  1.19.1.39
# 2  1.19.2.42
# 3  1.19.2.42
# 4  1.18.1.11
